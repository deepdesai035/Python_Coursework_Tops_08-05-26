# %% [markdown]
# # PYTHON REVISION QUESTIONS (SESSION 1 + SESSION 2)
#
#     Q1. Print "Welcome to Python" on screen.
#
#     Q2. Create a variable called city and store your city name.
#
# Print its datatype.
#
#     Q3. Store your age in a variable and check its type.
#
#     Q4. Take user input for marks and print its datatype.
#
# Why is it string?
#
#     Q5. Convert the marks input into float and print new datatype.
#     Q6. What is the difference between:
#
#         print(10 + 5)
#         print("10" + "5")

# %%
print("Welcome to python ")

city = "gandhinagar "
print(type(city))

age = 23
print(type(age))

user_marks = float(input("ENter your marks you want :- "))
print(type(user_marks))

user_marks_float = float(user_marks)

# q6 difference print(10 + 5) print the sumation addition operation where print("10 + "5") print eh contination output as they are strings
# Out:
# Welcome to python
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
#     Q7. Create a string "Programming" and print:
#
#         a) First character
#         b) Last Character
#
#     Q8. From "PythonProgramming", extract only "Python" using slicing.
#     Q9. Convert "data science" into uppercase.
#
#     Q10. Convert "MACHINE LEARNING" into lowercase.
#
#     Q11. Replace "Phone" with "Mobile" in "Apple Phone".
#
#     Q12. Split this sentence into words:
#
#         "Python is very powerful"
#
#     Q13. Use f-string to print:
#
#         My name is Rahul and age is 21
#
#     Q14. Clean this product name:
#
#         " samsung-Mobile "
#
#         Final output should be:
#             samsung mobile

# %%
    # Q7. Create a string "Programming" and print:

    #     a) First character
    #     b) Last Character


    a_string = "Programming"
    print(a_string[0])
    print(a_string[-1])


    # Q8. From "PythonProgramming", extract only "Python" using slicing.

    b_string = "PythonProgramming"
    print(b_string[:6])

    # Q9. Convert "data science" into uppercase.
    c_string = "data science"
    c_String = c_string.upper()
    print(c_String)

    # Q10. Convert "MACHINE LEARNING" into lowercase.

    d_string = "Machine Learning"
    d_string = d_string.lower()
    print(d_string)


    # Q11. Replace "Phone" with "Mobile" in "Apple Phone".

    e_string = "Apple Phone"
    e_string = e_string.replace ("Phone","Mobile")
    print(e_string)
# Out:
# P
# g
# Python
# DATA SCIENCE
# machine learning
# Apple Mobile

# %%
    # Q12. Split this sentence into words:

    #     "Python is very powerful"

    f_string = "Python is very powerful"
    words = f_string.split()
    print(words)

    # Q13. Use f-string to print:

    #     My name is Rahul and age is 21

    name = "Rahul"
    age = 21
    print(f"My name is {name} and age is {age}")
    
    # Q14. Clean this product name:

    #     " samsung-Mobile "

    #     Final output should be:
    #         samsung mobile

    product_name = "samsung-Mobile"
    product_name = product_name.replace("-"," ")
    print(product_name)
# Out:
# ['Python', 'is', 'very', 'powerful']
# My name is Rahul and age is 21
# samsung Mobile
