# %% [markdown]
# ### List practice question - 20-05-26

# %% [markdown]
# 1. Create a list named numbers containing: 10, 20, 30, 40.

# %%
numbers = [10,20,30,40,50]
print(numbers)
print(type(numbers))
# Out:
# [10, 20, 30, 40, 50]
# <class 'list'>

# %% [markdown]
# 2. Print the entire list.

# %%
print(numbers)
print(type(numbers))
# Out:
# [10, 20, 30, 40, 50]
# <class 'list'>

# %% [markdown]
# 3. Print the first element of the list.

# %%
print(numbers[0])
# Out:
# 10

# %% [markdown]
# 4. Print the last element of the list using negative indexing.

# %%
print(numbers[-1])
# Out:
# 50

# %% [markdown]
# 5. Find and print the length of the list.

# %%
print(len(numbers))
# Out:
# 5

# %% [markdown]
# 6. Add the number 50 to the end of the list.

# %%
numbers.append(50)
print(numbers)
print("this is a jupiter notebook everytime a cell is run it stores in the value in memeroy so when you print the list \n you will get the most latest output which include muiltiple 50 because this cell was run 3 before \n now again i edited thia and run for output 50 will be 4 times ")
# Out:
# [10, 20, 30, 40, 50, 50, 50, 50]
# this is a jupiter notebook everytime a cell is run it stores in the value in memeroy so when you print the list
#  you will get the most latest output which include muiltiple 50 because this cell was run 3 before
#  now again i edited thia and run for output 50 will be 4 times

# %% [markdown]
# 7. Insert the number 15 at index position 1.

# %%
numbers.insert(1,15)
print(numbers)
# Out:
# [10, 15, 10, 50, 20, 30, 40, 50, 50, 50, 50]

# %% [markdown]
# 8. Change the value 30 to 300 in the list.

# %%
numbers[numbers.index(12)] =300 # if value will not be there there will be error
print(numbers)

numbers[numbers.index(30)] =300
print(numbers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 numbers[numbers.index(12)] =300
#       2 print(numbers)
#       4 numbers[numbers.index(30)] =300
#
# ValueError: 12 is not in list

# %% [markdown]
# 9. Remove the value 20 from the list.

# %%
numbers.remove(10)
print(numbers)
# Out:
# [15, 10, 50, 300, 40, 50, 50, 50, 50]

# %% [markdown]
# 10. Remove the last element using pop().

# %%
numbers.pop()
print(numbers)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# 11. Create a list of 5 city names and print the third city.

# %%
city_name = ["pune", "Mumbai", "banglore", "Gandhinagar","manali"]
print(city_name[2])
# Out:
# banglore

# %% [markdown]
# 12. Create a list with duplicate values (example: 1, 2, 2, 3, 3). Print the list.

# %%
dup_list = [1,2,2,3,3]
print(dup_list)
# Out:
# [1, 2, 2, 3, 3]

# %% [markdown]
# 13. Sort the list [5, 2, 9, 1] in ascending order.

# %%
list = [5,2,9,1]
list.sort()
print(list)
# Out:
# [1, 2, 5, 9]

# %% [markdown]
# 14. Reverse the list [1, 2, 3, 4].

# %%
list = [1,2,3,4]
list.reverse()
print(list)
# Out:
# [4, 3, 2, 1]

# %% [markdown]
# 15. Create a list of marks (80, 85, 90, 95) and print:
# o Maximum marks
# o Minimum marks
# o Average marks

# %%
marks_list = [80,85,90,95]

print("the maimum marks:- ", max(marks_list))
print("the minimum marks :- ", min(marks_list))
print("the average marks :- ", (sum(marks_list)/len(marks_list)))
# Out:
# the maimum marks:-  95
# the minimum marks :-  80
# the average marks :-  87.5
