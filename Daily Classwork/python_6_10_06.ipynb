# %% [markdown]
# ## Functions completed practice question :

# %% [markdown]
# Function Practice Questions

# %% [markdown]
# 1. Write a function called greet that prints the message Welcome to Python when called.

# %%
def greet():
    print("Welcome to the python")

greet()
# Out:
# Welcome to the python

# %% [markdown]
# 2. Write a function called show_number that takes a number as argument and prints the number.

# %%
def show_cumber(a):
    print(a)

number = input("nter the number")
show_cumber(number)
# Out:
# 12

# %% [markdown]
# 3. Write a function called square that takes a number as input and prints its square.

# %%
def square(a):
    print(a*a)


number = int(input("enter the number:-"))

square(number)
# Out:
# 144

# %% [markdown]
# 4. Write a function called add_numbers that takes two numbers as arguments and prints their sum.

# %%
def add_numbers(a,b):
    print(a+b)

number1 = int(input("enter the number:- "))
number2 = int(input("Enter the number:- "))

add_numbers(number1 , number2)
# Out:
# 2454

# %% [markdown]
# 5. Write a function called display_name that takes a name as input and prints Hello followed by the name.

# %%
def display_name(fullname):
    print(f"hello mister :- {fullname}")

name1 = input("enter the name :- ")

display_name(name1)
# Out:
# hello mister :- deep desi

# %% [markdown]
# 6. Write a function called multiply that takes two numbers as arguments and returns their product.

# %%
def multiply(a,b):
    return a*b

num1 = int(input("enter the number 1 :- "))

num2 = int(input("Enter the number 2 :- "))

multiply(num1 , num2)

print(multiply(num1 , num2))
# Out:
# 144

# %% [markdown]
# 7. Write a function called find_max that takes two numbers as arguments and returns the larger number.

# %%
def find_max(a,b):
    if a>b:
        return a
    else:
        return b

num1 = int(input("enter the number: -"))
num2 = int(input("enter the number :- "))

print(find_max(num1 , num2))
# Out:
# 21312

# %% [markdown]
# 8. Write a function called calculate_area that takes the radius of a circle as argument and returns the area of the circle.

# %%
def calculate_area(rad):
    return 3.14 *rad*rad

radius = int(input("enter the radius"))

print(calculate_area(radius))
# Out:
# 6.28

# %% [markdown]
# 9. Write a function called calculate_discount that takes price and rate as arguments and returns the final price after discount.

# %%
def calculate_discount(price1 , disrate):
    return price1 -(price1*disrate/100)

price = int(input("enter the price :- "))
discount = int(input("enter the discount:- "))

print(calculate_discount(price , discount))
# Out:
# 90.0

# %% [markdown]
# 10. Write a function called check_even that takes a number as argument and prints whether the number is even or odd.

# %%
def check_even(num1):
    if num1%2 == 0:
        print("even")
    else:
        print("odd")

number1 = int(input("enter the num:--"))

check_even(number1)
# Out:
# odd

# %% [markdown]
# 11. Write a function called average_numbers that takes three numbers as arguments and returns their average.

# %%
def average_number(a,b,c):
    return (a+b+c)/3

a = int(input("Enter three numbers "))
b = int(input("Enter three numbers "))
c = int(input("Enter three numbers "))

print(average_number(a,b,c))
# Out:
# 2.3333333333333335

# %% [markdown]
# 12. Write a function called find_largest that takes a list of numbers as argument and returns the largest value in the list.

# %%
def find_largest(num1):
    return max(num1)

list1 = []
num1 = 1
while num1 != 0:
    num1 = int(input("enter the number"))
    list1.append(num1)



print(find_largest(list1))
# Out:
# 9

# %% [markdown]
# 13. Write a function called count_digits that takes a number as argument and returns the number of digits in that number.

# %%
def count_digits(number1):
    count = 0
    while number1 != 0:
        number1 = number1//10
        count = count +1
    return count    

numbe = int(input("enter the number you wan tto count digit:----"))

print(count_digits(numbe))
# Out:
# 17

# %% [markdown]
# 14. Write a function called total_sales that takes a list of sales values as argument and returns the total sales.

# %%
def total_sales(list1):
    return sum(list1)

count = 1
list = []

# %% [markdown]
# 15. Write a function called clean_product_name that takes a string as argument and performs the following operations
#
# convert the string to lowercase
#
# remove extra spaces from beginning and end
#
# replace any dash with a space
#
# return the cleaned product name

# %%
def clean_product_name(string3):
    string3 = string1.lower()
    string3 = string1.replace(" ","")
    string3 = string1.replace("-" ," ")
    return string3

string2 = input("enter the string:- ")

print((clean_product_name(string2)))
print(string3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       5     return string3
#       7 string2 = input("enter the string:- ")
# ----> 9 print((clean_product_name(string2)))
#      10 print(string3)
#
# Cell In[6], line 2, in clean_product_name(string3)
#       1 def clean_product_name(string3):
# ----> 2     string3 = string1.lower()
#       3     string3 = string1.replace(" ","")
#       4     string3 = string1.replace("-" ," ")
#
# NameError: name 'string1' is not defined
