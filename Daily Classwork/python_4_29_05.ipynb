# %% [markdown]
# ## python file -4 :- nested if

# %% [markdown]
# ### if a person is adult then can vote for either of the party

# %%
your_age = innnn

# %%
## age 

your_age = int(input("ENter your age :- "))

if your_age >60:
    print("buddha hoga tera baap")
elif your_age >18:
    print("tumhe license mil sakta bhai tum 18 ke upar ho")    
elif your_age >13:
    print("beta tu bachaa he ")
else:
    print("you are bacha")
# Out:
# buddha hoga tera baap

# %%
## nested if with age 

your_age = int(input("ENter your age :- "))

if your_age >13:
    if your_age >70:
        print("buddha")
    elif your_age >18:
        print("adult")
    else:
        print("teenager")
else:
    print("you are a child")
# Out:
# you are a child

# %%
## revnue with region 

target = int(input("ENter the target - "))
revenue = int(input("ENter the renvenue:- "))
region = input("enter your region ")

if revenue > target:
    if region == "North":
        print("the Target of North region is achieved")
    elif region == "South":
        print("the south region target ws achiebed")
    else:
        print("the unknown region target ws achieved")        
else:
    print("the target wa not achived :- ")
# Out:
# the south region target ws achiebed
