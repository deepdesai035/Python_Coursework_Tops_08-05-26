# %% [markdown]
# # type conversion

# %%
set1 = {1,2,3,4,54,5,6,56,75,8,87,87,9}
list1 = list(set1)
print(list1)
list1.append(75)
print(list1)
tuple1 = tuple(set1)
print(set1)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 75, 54, 87, 56]
# [1, 2, 3, 4, 5, 6, 8, 9, 75, 54, 87, 56, 75]
# {1, 2, 3, 4, 5, 6, 8, 9, 75, 54, 87, 56}

# %%
# discount price 

total_invoice_value = float(input("Enter the total invoice value"))
discounted_price = 0 

if total_invoice_value >= 1000.0:
    discounted_price = total_invoice_value - (total_invoice_value*0.3)
    print(f"Congratination we are giving you 30 per discount your final amount is {discounted_price}")

elif total_invoice_value >= 500.0:
    discounted_price = total_invoice_value - (total_invoice_value*0.2)
    print(f"Congratination we are giving you 20 per discount your final amount is {discounted_price}")

elif total_invoice_value >= 200.0:
    discounted_price = total_invoice_value - (total_invoice_value*0.1)
    print(f"Congratination we are giving you 10 per discount your final amount is {discounted_price}")
else:
    discounted_price = total_invoice_value
    print(f" your final amount is {discounted_price}")
# Out:
# Congratination we are giving you 30 per discount your final amount is 700.0

# %%
income = int(input("please enter your income do not hesitate to enter the correct amount :-  "))

if income >= 200000:
    print("Sir you can afford Honda City")
elif income >= 150000:
   print("congrats bro you can have Grand vitara")  
elif income >= 100000:
   print("beta you can have altroz ")
elif income >=50000:
   print("bhai tu alto le sakta bhai Lord Alto ")
else:
   print(" bhai tu uber book kar ")
# Out:
#  bhai tu rapido book kar
