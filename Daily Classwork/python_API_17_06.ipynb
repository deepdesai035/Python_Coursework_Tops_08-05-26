# %% [markdown]
# API - 17-06-26

# %% [markdown]
# ## What is API - application programming interface
#
#  model - python - user use
#
# langauage independent
#
# code security
#
#  client side - chat gpt - prompt - request - api - pass - to server - response -
#
#  chatgpt - model - python - website /react - cross language
#
# # 2 types of API
#
# 1. Rest  - no protocaol  , low bandwidth , less secure
#
# 2. Soap - need to follow protocol , high bandwidth , more secure
#
# ### code - convert into - url
#
# url - API end point
#
#
# ## formats to store the data
#
# Rest - json , xml ,
#
# ## API operations
#
# methods , - get (select query ), post (insert query ), put (updare query - all columns ),petch (single column update ) , delete (delete method)
#
# postman
