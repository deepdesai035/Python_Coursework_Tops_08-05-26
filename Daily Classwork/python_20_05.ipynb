# %%
list1 = [1,2,3,4,'deep','desai']
list2 = [5,6,7,8,'desai','pravin']

# %%
# list operation , 
# append 

list1.append(10)
print(list1)
# insert

list1.insert(2,100)
print(list1)

#remove 
list1.remove(100)
print(list1)

# pop

list1.pop()
# Out:
# [1, 2, 3, 4, 'deep', 'desai', 10]
# [1, 2, 100, 3, 4, 'deep', 'desai', 10]
# [1, 2, 3, 4, 'deep', 'desai', 10]
# 10

# %%
# sorting the List 

list1 = [1,2,3,5,4,5,6,6,]

print(list1.sort())
print(list1.reverse())
print(None)
# Out:
# None
# None
# None
