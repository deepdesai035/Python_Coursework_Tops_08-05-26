# %%
print("Hello World")
# Out:
# Hello World

# %%
# comment here

"""hello comment
hello  triple line comment 
ello """
# Out:
# 'hello comment\nhello  triple line comment \nello '

# %%
#variables

name = "deep desai here "
id_number = 995156
percentage = 'deep'
check = True

# %%
# Type function

print(type(name))
print(type(id_number))
print(type(percentage))
print(type(check))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %%
#input

user_age = input("Enter age of your brother heheh")
print(user_age)
# Out:
# 0999999
