# %%
# why datatype matters 
print(10+5)
print('10'+'5')
# Out:
# 15
# 105

# %%
#concatenation operation on Strings , use case is to join the full name with concatenation function

a= input("Enter your first Name:")
b= input("Enter your last name:")
c= a+" "+b
print(c)


#aother example is mobile number 
a = int(input("enter you country code -"))
b= int(input("enter your mobile number - "))

c = int(str(a)+str(b))

print(c)
print(type(c))
# Out:
# deep desai
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 10
#       6 print(c)
#       9 #aother example is mobile number
# ---> 10 a = int(input("enter you country code -"))
#      11 b= int(input("enter your mobile number - "))
#      13 c = int(str(a)+str(b))
#
# ValueError: invalid literal for int() with base 10: 'deep'

# %%
name = "10"
na = int(name)
print(na)
print(type(na))
# Out:
# 10
# <class 'int'>
